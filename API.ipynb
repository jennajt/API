# %% [markdown]
# # Enrich a CSV with data from an API
#
# Data sources:
#
# - The [Goodreads books](https://www.kaggle.com/jealousleopard/goodreadsbooks) dataset from Kaggle.
# - The [Open Library Books API](https://openlibrary.org/dev/docs/api/books)
#
# The goal is to enrich the Kaggle dataset with additional information from the Open Library Books API
#
# - The cover URL of the book
# - List of subjects (Science, Humor, Travel, etc.)
#
# This notebook is adapted from the Le Wagon Data Science Bootcamp challenge

# %%
# imports
import requests
import numpy as np
import pandas as pd

# %%
# load csv from Kaggle
books_df = pd.read_csv('books.csv', on_bad_lines='skip')
books_df.head(10)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 5       9  Unauthorized Harry Potter Book Seven News: "Ha...
# 6      10       Harry Potter Collection (Harry Potter  #1-6)
# 7      12  The Ultimate Hitchhiker's Guide: Five Complete...
# 8      13  The Ultimate Hitchhiker's Guide to the Galaxy ...
# 9      14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
# 5      W. Frederick Zimmerman            3.74  0976540606  9780976540601
# 6                J.K. Rowling            4.73  0439827604  9780439827607
# 7               Douglas Adams            4.38  0517226952  9780517226957
# 8               Douglas Adams            4.38  0345453743  9780345453747
# 9               Douglas Adams            4.22  1400052920  9781400052929
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
# 5         en-US          152             19                   1
# 6           eng         3342          28242                 808
# 7           eng          815           3628                 254
# 8           eng          815         249558                4080
# 9           eng          215           4930                 460
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic
# 5        4/26/2005     Nimble Books
# 6        9/12/2005       Scholastic
# 7        11/1/2005   Gramercy Books
# 8        4/30/2002    Del Rey Books
# 9         8/3/2004            Crown

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Add cover URL from API

# %%
def fetch_cover(isbn):
    url = f'http://openlibrary.org/api/books?bibkeys=ISBN:{isbn}&jscmd=data&format=json'
    response = requests.get(url)
    if response.status_code != 200:
        return ''
    data = response.json()
    if f"ISBN:{isbn}" in data:
        if 'cover' in data[f'ISBN:{isbn}'].keys():
            return data[f'ISBN:{isbn}']['cover']['small']
        return 'No cover URL available'
    return ''

# %%
# test cover
print(fetch_cover('0439785960'))
print(fetch_cover('0345453743'))
# Out:
# https://covers.openlibrary.org/b/id/9326654-S.jpg
# No cover URL available

# %%
# create new column
books_df['Cover URL']=''
books_df.head(1)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
#
#   publication_date        publisher Cover URL
# 0        9/16/2006  Scholastic Inc.

# %%
# %%time
# Fetch cover URL for first 200 books in the DF
for index, row in books_df.sample(200).iterrows():
    print(f"Fetching Cover URL for {row['authors']} - {row['title']}")
    cover = fetch_cover(row['isbn'])
    books_df.loc[index, 'Cover URL'] = cover
# Out:
# Fetching Cover URL for Deborah Blum - Ghost Hunters: William James and the Search for Scientific Proof of Life After Death
# Fetching Cover URL for Orson Scott Card/Piotr W. Cholewa - Xenocide (Ender's Saga  #3)
# Fetching Cover URL for L.M. Montgomery/Susan O'Malley - Anne of Avonlea
# Fetching Cover URL for Georg Wilhelm Friedrich Hegel - The Essential Writings
# Fetching Cover URL for Hideyuki Kikuchi/Yoshitaka Amano - Vampire Hunter D Volume 07: Mysterious Journey to the North Sea - Part One
# Fetching Cover URL for William J. Bennett - From the Age of Discovery to a World at War (America: The Last Best Hope #1)
# Fetching Cover URL for Richard M. Weaver - Ideas Have Consequences
# Fetching Cover URL for Junichi Satō/Kaori Naruse - Prétear  Vol. 4 (Prétear  #4)
# Fetching Cover URL for Robin McKinley - Spindle's End
# Fetching Cover URL for Luigi Pirandello/Henry Reed - Collected Plays: Henry IV  The Man with the Flower in His Mouth  Right You Are
# Fetching Cover URL for Tess Gerritsen - Vanish (Rizzoli & Isles  #5)
# Fetching Cover URL for Frances Oliver - Dancing On Air
# Fetching Cover URL for Andy McNab - Bravo Two Zero
# Fetching Cover URL for Raymond E. Feist - Magician: Apprentice (The Riftwar Saga  #1)
# Fetching Cover URL for Jaroslav Hašek - Good Soldier Svejk And His Fortunes In The World
# Fetching Cover URL for Roald Dahl - Fantastic Mr Fox and Other Animal Stories
# Fetching Cover URL for Marcel Proust/C.K. Scott Moncrieff/Terence Kilmartin/D.J. Enright - The Captive & The Fugitive (In Search of Lost Time  #5-6)
# Fetching Cover URL for Douglas Preston/Lincoln Child - Reliquary (Pendergast  #2)
# Fetching Cover URL for Hiromu Arakawa/Akira Watanabe - Fullmetal Alchemist  Vol. 8 (Fullmetal Alchemist  #8
# Fetching Cover URL for John C. Maxwell/Les Parrott III - 25 Ways to Win with People: How to Make Others Feel Like a Million Bucks
# Fetching Cover URL for William Empson - Seven Types of Ambiguity
# Fetching Cover URL for Seamus Deane - Reading in the Dark
# Fetching Cover URL for Robin McKinley - The Hero and the Crown (Damar  #2)
# Fetching Cover URL for Michael Littlefield - Lego Star Wars: Prima Official Game Guide
# Fetching Cover URL for Homer/Sheila Murnaghan/Stanley Lombardo - The Essential Iliad
# Fetching Cover URL for James Fenimore Cooper/Blake Nevius - The Leatherstocking Tales  Vol. 2: The Pathfinder / The Deerslayer
# Fetching Cover URL for Andrew X. Pham - Catfish and Mandala: A Two-Wheeled Voyage Through the Landscape and Memory of Vietnam
# Fetching Cover URL for George Orwell/Richard H. Rovere - The Orwell Reader: Fiction  Essays  and Reportage
# Fetching Cover URL for Robert B. Parker/David Dukes - Thin Air (Spenser  #22)
# Fetching Cover URL for Bill Watterson - The Complete Calvin and Hobbes
# Fetching Cover URL for Mayu Shinjō - Sensual Phrase  Vol. 15
# Fetching Cover URL for David Almond - Skellig: The Play
# Fetching Cover URL for Wally Lamb - She's Come Undone
# Fetching Cover URL for Virginia Woolf/Nigel Nicolson/Joanne Trautmann - The Letters of Virginia Woolf: Volume Six  1936-1941
# Fetching Cover URL for Miguel de Cervantes Saavedra/Tobias Smollett/Carlos Fuentes - Don Quixote
# Fetching Cover URL for James Plath - Conversations with John Updike
# Fetching Cover URL for Donna Woolfolk Cross - Pope Joan
# Fetching Cover URL for Mark Allen Weiss - Data Structures and Algorithm Analysis in C
# Fetching Cover URL for P.G. Wodehouse - Eggs  Beans  and Crumpets
# Fetching Cover URL for Laura Driscoll/Alisa Klayman-Grodsky/Eric     Weiner - Tyrannosaurus Wrecks (Stanley  #1)
# Fetching Cover URL for Georg Wilhelm Friedrich Hegel/J. Sibree - The Philosophy of History
# Fetching Cover URL for Augustine of Hippo/J.M. Lelen - Confessions of Saint Augustine (Paraclete Living Library)
# Fetching Cover URL for Terry Brooks/George Lucas - The Phantom Menace (Star Wars: Novelizations  #1)
# Fetching Cover URL for Peter Carey - Theft: A Love Story
# Fetching Cover URL for Larry Burkett - The Illuminati

# %%
# Check the DF
books_df.head(10)

# %% [markdown]
# ## Add subject name for API

# %%
def fetch_subject(isbn):
    url = f'http://openlibrary.org/api/books?bibkeys=ISBN:{isbn}&jscmd=data&format=json'
    response = requests.get(url)
    if response.status_code != 200:
        return ''
    data = response.json()
    if f"ISBN:{isbn}" in data:
        if 'subjects' in data[f'ISBN:{isbn}'].keys():
            return data[f'ISBN:{isbn}']['subjects'][0]['name']
        return 'No subject name available'
    return ''

# %%
# test function
fetch_subject('1400052920')

# %%
# create new column
books_df['Subject']=''
books_df.head(1)

# %%
# %%time
# Fetch subject for first 200 books in the DF
for index, row in books_df.sample(200).iterrows():
    print(f"Fetching subject for {row['authors']} - {row['title']}")
    subject = fetch_subject(row['isbn'])
    books_df.loc[index, 'Subject'] = subject

# %%
# Check the DF
books_df.head(10)
